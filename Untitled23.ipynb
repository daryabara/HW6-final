# %% [markdown]
# <a href="https://colab.research.google.com/github/daryabara/HW6-final/blob/main/Untitled23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas numpy matplotlib seaborn scikit-learn statsmodels
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (0.13.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.11/dist-packages (0.14.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.11/dist-packages (from statsmodels) (1.0.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.cluster import KMeans, DBSCAN, AgglomerativeClustering
from sklearn.mixture import GaussianMixture
from sklearn.ensemble import IsolationForest, RandomForestRegressor, VotingRegressor, GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.model_selection import train_test_split
from prophet import Prophet
from xgboost import XGBRegressor
import warnings

warnings.filterwarnings('ignore')

# генерация датасета

np.random.seed(42)
data_size = 2000  # 2000 наблюдений

products = ["Эспрессо", "Американо", "Капучино", "Латте", "Раф",
           "Чай зеленый", "Чай черный", "Круассан классический",
           "Круассан миндальный", "Тарталетка лимонная",
           "Тарталетка с соленой карамелью", "Ролл с ветчиной и сыром",
           "Ролл с лососем и творожным сыром"]
prices = [2, 4, 7, 7, 9, 5, 5, 6, 9, 8, 9, 10, 11]

dates = pd.date_range('2024-01-01', '2025-05-06', periods=data_size)
times = [f"{np.random.randint(8, 22)}:{np.random.randint(0, 60):02d}" for _ in range(data_size)]

data = {
    'transaction_id': np.arange(1000, 1000 + data_size),
    'datetime': [d + pd.Timedelta(minutes=int(t.split(':')[1]), hours=int(t.split(':')[0]))
                for d, t in zip(dates, times)],
    'client_id': np.random.randint(1, 301, size=data_size),  # 300 уникальных клиентов
    'age': np.random.normal(loc=35, scale=10, size=data_size).astype(int).clip(16, 70),
    'gender': np.random.choice(['М', 'Ж'], size=data_size, p=[0.4, 0.6]),
    'product': np.random.choice(products, size=data_size, p=[0.15, 0.1, 0.2, 0.15, 0.05, 0.05, 0.05, 0.05, 0.03, 0.04, 0.03, 0.05, 0.05]),
    'quantity': np.random.choice([1, 2, 3, 4], size=data_size, p=[0.6, 0.25, 0.1, 0.05]),
    'price': [prices[products.index(p)] for p in np.random.choice(products, size=data_size, p=[0.15, 0.1, 0.2, 0.15, 0.05, 0.05, 0.05, 0.05, 0.03, 0.04, 0.03, 0.05, 0.05])],
    'payment_method': np.random.choice(['Карта', 'Наличные', 'Мобильный'], size=data_size, p=[0.6, 0.3, 0.1]),
    'loyalty_card': np.random.choice([True, False], size=data_size, p=[0.4, 0.6])
}

df = pd.DataFrame(data)
df['total_price'] = df['price'] * df['quantity']
df['day_of_week'] = df['datetime'].dt.day_name()
df['hour'] = df['datetime'].dt.hour
df['month'] = df['datetime'].dt.month_name()
df['is_weekend'] = df['day_of_week'].isin(['Saturday', 'Sunday'])
df['time_of_day'] = pd.cut(df['hour'], bins=[0, 11, 16, 24], labels=['Утро', 'День', 'Вечер'], include_lowest=True)

# 2. Описание данных
print("\n=== Описание колонок ===")
column_description = {
    'transaction_id': 'Уникальный идентификатор операции',
    'datetime': 'Дата и время покупки',
    'client_id': 'Уникальный идентификатор клиента',
    'age': 'Возраст клиента (16-70 лет)',
    'gender': 'Пол клиента (М/Ж)',
    'product': 'Название товара',
    'quantity': 'Количество товара в покупке (1-4)',
    'price': 'Цена за единицу товара',
    'payment_method': 'Способ оплаты',
    'loyalty_card': 'Наличие карты лояльности',
    'total_price': 'Общая сумма покупки',
    'day_of_week': 'День недели',
    'hour': 'Час покупки (8-22)',
    'month': 'Месяц покупки',
    'is_weekend': 'Покупка в выходной день',
    'time_of_day': 'Время дня (Утро/День/Вечер)'
}

for col, desc in column_description.items():
    print(f"{col}: {desc}")

# 3. EDA Анализ
print("\n=== EDA Анализ ===")

# 3.1 Общая информация
print("\nПервые 5 строк:")
display(df.head())

print("\nИнформация о датасете:")
print(df.info())

print("\nСтатистика по числовым колонкам:")
display(df.describe())

print("\nСтатистика по категориальным колонкам:")
display(df.describe(include=['object', 'bool']))

# 3.2 Проверка на пропуски
print("\nПропущенные значения:")
print(df.isnull().sum())

# 3.3 Визуализация распределений
plt.figure(figsize=(18, 12))

# Распределение продаж по товарам
plt.subplot(2, 2, 1)
df['product'].value_counts().plot(kind='bar')
plt.title('Распределение продаж по товарам')
plt.xticks(rotation=45)

# Распределение по времени дня
plt.subplot(2, 2, 2)
df['time_of_day'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Распределение по времени дня')

# Распределение суммы покупок
plt.subplot(2, 2, 3)
sns.histplot(df['total_price'], bins=30, kde=True)
plt.title('Распределение суммы покупок')

# Распределение по способам оплаты
plt.subplot(2, 2, 4)
df['payment_method'].value_counts().plot(kind='bar')
plt.title('Способы оплаты')

plt.tight_layout()
plt.show()

# 4. Предобработка данных

print("\n=== Предобработка данных ===")

# 4.1 Кодирование категориальных признаков
cat_cols = ['product', 'payment_method', 'day_of_week', 'gender', 'month', 'time_of_day']
df_encoded = pd.get_dummies(df, columns=cat_cols)

# 4.2 Масштабирование числовых признаков
num_cols = ['age', 'quantity', 'price', 'total_price', 'hour']
scaler = StandardScaler()
df_encoded[num_cols] = scaler.fit_transform(df_encoded[num_cols])

# 5. Анализ временных рядов (5 подходов)

print("\n=== Анализ временных рядов ===")

# Подготовка данных
ts_data = df.set_index('datetime')['total_price'].resample('D').sum()

# 5.1 Декомпозиция временного ряда
decomposition = seasonal_decompose(ts_data, model='additive', period=30)
decomposition.plot()
plt.suptitle('Декомпозиция временного ряда', y=1.02)
plt.show()

# 5.2 Prophet
print("\n=== Модель Prophet ===")
df_prophet = ts_data.reset_index()
df_prophet.columns = ['ds', 'y']
train_size = int(len(df_prophet) * 0.8)
train, test = df_prophet.iloc[:train_size], df_prophet.iloc[train_size:]

model_prophet = Prophet(
    yearly_seasonality=True,
    weekly_seasonality=True,
    daily_seasonality=False,
    changepoint_prior_scale=0.05
)
model_prophet.fit(train)
future = model_prophet.make_future_dataframe(periods=len(test))
forecast_prophet = model_prophet.predict(future)

# Визуализация прогноза
fig = model_prophet.plot(forecast_prophet)
plt.title('Прогноз Prophet')
plt.show()

# 5.3 Exponential Smoothing
print("\n=== Exponential Smoothing ===")
model_ets = ExponentialSmoothing(
    ts_data,
    seasonal='add',
    seasonal_periods=7
).fit()
forecast_ets = model_ets.forecast(len(test))

# 5.4 Random Forest для временных рядов
print("\n=== Random Forest для временных рядов ===")
def create_features(df, label=None):
    df = df.copy()
    df['dayofweek'] = df.index.dayofweek
    df['quarter'] = df.index.quarter
    df['month'] = df.index.month
    df['dayofyear'] = df.index.dayofyear
    if label:
        df[label] = df[label]
    return df

ts_features = create_features(ts_data.to_frame('total_price'))
X = ts_features.drop('total_price', axis=1)
y = ts_features['total_price']
X_train, X_test = X.iloc[:train_size], X.iloc[train_size:]
y_train, y_test = y.iloc[:train_size], y.iloc[train_size:]

model_rf = RandomForestRegressor(n_estimators=100, random_state=42)
model_rf.fit(X_train, y_train)
forecast_rf = model_rf.predict(X_test)

# 5.5 Gradient Boosting
print("\n=== Gradient Boosting ===")
model_gb = GradientBoostingRegressor(n_estimators=100, random_state=42)
model_gb.fit(X_train, y_train)
forecast_gb = model_gb.predict(X_test)

# 5.6 XGBoost
print("\n=== XGBoost ===")
model_xgb = XGBRegressor(n_estimators=100, random_state=42)
model_xgb.fit(X_train, y_train)
forecast_xgb = model_xgb.predict(X_test)

# Визуализация всех прогнозов
plt.figure(figsize=(16, 8))
plt.plot(ts_data.index, ts_data.values, label='Фактические данные', color='blue')
plt.plot(test['ds'], test['y'], label='Тестовые данные', color='green')
plt.plot(forecast_prophet['ds'], forecast_prophet['yhat'], label='Prophet', linestyle='--')
plt.plot(test['ds'], forecast_ets.values, label='ETS', linestyle='--')
plt.plot(X_test.index, forecast_rf, label='Random Forest', linestyle='--')
plt.plot(X_test.index, forecast_gb, label='Gradient Boosting', linestyle='--')
plt.plot(X_test.index, forecast_xgb, label='XGBoost', linestyle='--')
plt.title('Сравнение моделей временных рядов')
plt.legend()
plt.grid()
plt.show()


# 6. Ансамбль моделей
print("\n=== Ансамбль моделей ===")
ensemble = VotingRegressor([
    ('rf', model_rf),
    ('gb', model_gb),
    ('xgb', model_xgb)
])
ensemble.fit(X_train, y_train)
forecast_ensemble = ensemble.predict(X_test)

# Оценка качества
models = {
    'Prophet': forecast_prophet.iloc[-len(test):]['yhat'],
    'ETS': forecast_ets,
    'Random Forest': forecast_rf,
    'Gradient Boosting': forecast_gb,
    'XGBoost': forecast_xgb,
    'Ансамбль': forecast_ensemble
}

results = []
for name, pred in models.items():
    mae = mean_absolute_error(test['y'], pred[-len(test):])
    mape = mean_absolute_percentage_error(test['y'], pred[-len(test):]) * 100
    results.append([name, mae, mape])

metrics_df = pd.DataFrame(results, columns=['Model', 'MAE', 'MAPE'])
print("\nСравнение моделей:")
display(metrics_df.sort_values('MAE'))

# 7. Поиск аномалий
print("\n=== Поиск аномалий ===")

# 7.1 Isolation Forest
iso = IsolationForest(contamination=0.05, random_state=42)
df['anomaly_score'] = iso.fit_predict(df[['total_price', 'quantity']])
df['anomaly'] = df['anomaly_score'].apply(lambda x: 1 if x == -1 else 0)

# 7.2 Визуализация аномалий
plt.figure(figsize=(12, 6))
sns.scatterplot(data=df, x='datetime', y='total_price', hue='anomaly', palette='viridis')
plt.title('Выявление аномалий в продажах')
plt.xticks(rotation=45)
plt.show()

# 8. Визуализация результатов
print("\n=== Визуализация результатов ===")

# 8.1 График ошибок ансамблевой модели
errors = test['y'] - forecast_ensemble[-len(test):]
plt.figure(figsize=(10, 5))
sns.histplot(errors, bins=30, kde=True)
plt.title('Распределение ошибок ансамблевой модели')
plt.xlabel('Ошибка прогноза')
plt.show()

# 8.2 Важность признаков для Random Forest
feature_importances = pd.Series(model_rf.feature_importances_, index=X.columns)
plt.figure(figsize=(12, 6))
feature_importances.sort_values().plot(kind='barh')
plt.title('Важность признаков (Random Forest)')
plt.show()

# 8.3 Сравнение метрик качества
plt.figure(figsize=(12, 6))
sns.barplot(data=metrics_df, y='Model', x='MAE', palette='viridis')
plt.title('Сравнение MAE моделей')
plt.show()
# Out:
# === Описание колонок ===
# transaction_id: Уникальный идентификатор операции
# datetime: Дата и время покупки
# client_id: Уникальный идентификатор клиента
# age: Возраст клиента (16-70 лет)
# gender: Пол клиента (М/Ж)
# product: Название товара
# quantity: Количество товара в покупке (1-4)
# price: Цена за единицу товара
# payment_method: Способ оплаты
# loyalty_card: Наличие карты лояльности
# total_price: Общая сумма покупки
# day_of_week: День недели
# hour: Час покупки (8-22)
# month: Месяц покупки
# is_weekend: Покупка в выходной день
# time_of_day: Время дня (Утро/День/Вечер)
#
# === EDA Анализ ===
#
# Первые 5 строк:
#    transaction_id                      datetime  client_id  age gender  \
# 0            1000 2024-01-01 14:51:00.000000000        173   28      Ж
# 1            1001 2024-01-02 02:07:41.810905452        206   45      М
# 2            1002 2024-01-02 05:54:23.621810905         63   43      Ж
# 3            1003 2024-01-02 14:01:05.432716358         73   24      Ж
# 4            1004 2024-01-02 14:31:47.243621810        251   44      Ж
#
#      product  quantity  price payment_method  loyalty_card  total_price  \
# 0      Латте         1      2          Карта         False            2
# 1   Капучино         3      9      Мобильный          True           27
# 2   Капучино         1      9      Мобильный         False            9
# 3  Американо         3      9          Карта          True           27
# 4      Латте         1      7       Наличные          True            7
#
#   day_of_week  hour    month  is_weekend time_of_day
# 0      Monday    14  January       False        День
# 1     Tuesday     2  January       False        Утро
# 2     Tuesday     5  January       False        Утро
# 3     Tuesday    14  January       False        День
# 4     Tuesday    14  January       False        День
# Информация о датасете:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   transaction_id  2000 non-null   int64
#  1   datetime        2000 non-null   datetime64[ns]
#  2   client_id       2000 non-null   int64
#  3   age             2000 non-null   int64
#  4   gender          2000 non-null   object
#  5   product         2000 non-null   object
#  6   quantity        2000 non-null   int64
#  7   price           2000 non-null   int64
#  8   payment_method  2000 non-null   object
#  9   loyalty_card    2000 non-null   bool
#  10  total_price     2000 non-null   int64
#  11  day_of_week     2000 non-null   object
#  12  hour            2000 non-null   int32
#  13  month           2000 non-null   object
#  14  is_weekend      2000 non-null   bool
#  15  time_of_day     2000 non-null   category
# dtypes: bool(2), category(1), datetime64[ns](1), int32(1), int64(6), object(5)
# memory usage: 201.4+ KB
# None
#
# Статистика по числовым колонкам:
#        transaction_id                       datetime    client_id  \
# count     2000.000000                           2000  2000.000000
# mean      1999.500000  2024-09-03 02:59:37.770000128   150.229500
# min       1000.000000            2024-01-01 14:51:00     1.000000
# 25%       1499.750000            2024-05-03 08:44:30    75.000000
# 50%       1999.500000            2024-09-03 01:25:30   150.000000
# 75%       2499.250000  2025-01-03 20:06:20.905452800   222.000000
# max       2999.000000            2025-05-06 19:19:00   300.000000
# std        577.494589                            NaN    85.139075
#
#                age     quantity        price  total_price         hour
# count  2000.000000  2000.000000  2000.000000    2000.0000  2000.000000
# mean     34.491500     1.593000     6.273000      10.0230    11.418000
# min      16.000000     1.000000     2.000000       2.0000     0.000000
# 25%      28.000000     1.000000     4.000000       5.0000     6.000000
# 50%      34.000000     1.000000     7.000000       7.0000    11.000000
# 75%      41.000000     2.000000     7.000000      14.0000    17.000000
# max      70.000000     4.000000    11.000000      44.0000    23.000000
# std       9.648859     0.859488     2.508708       7.1857     6.877931
# Статистика по категориальным колонкам:
#        gender   product payment_method loyalty_card day_of_week  month  \
# count    2000      2000           2000         2000        2000   2000
# unique      2        13              3            2           7     12
# top         Ж  Капучино          Карта        False      Monday  March
# freq     1230       422           1224         1171         294    252
#
#        is_weekend
# count        2000
# unique          2
# top         False
# freq         1429
# Пропущенные значения:
# transaction_id    0
# datetime          0
# client_id         0
# age               0
# gender            0
# product           0
# quantity          0
# price             0
# payment_method    0
# loyalty_card      0
# total_price       0
# day_of_week       0
# hour              0
# month             0
# is_weekend        0
# time_of_day       0
# dtype: int64
# === Предобработка данных ===
#
# === Анализ временных рядов ===
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp28_fe5q3/5x7go1lj.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp28_fe5q3/qh47423a.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=87007', 'data', 'file=/tmp/tmp28_fe5q3/5x7go1lj.json', 'init=/tmp/tmp28_fe5q3/qh47423a.json', 'output', 'file=/tmp/tmp28_fe5q3/prophet_model07bc6430/prophet_model-20250506062032.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:20:32 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:20:32 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# === Модель Prophet ===
# === Exponential Smoothing ===
#
# === Random Forest для временных рядов ===
#
# === Gradient Boosting ===
#
# === XGBoost ===
# === Ансамбль моделей ===
#
# Сравнение моделей:
#                Model        MAE       MAPE
# 1                ETS  13.485167  39.234438
# 3  Gradient Boosting  13.861428  40.040735
# 0            Prophet  14.343483  44.941269
# 5           Ансамбль  15.049408  42.609631
# 2      Random Forest  15.263030  42.761346
# 4            XGBoost  16.697206  46.498886
# === Поиск аномалий ===
# === Визуализация результатов ===
